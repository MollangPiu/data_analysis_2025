# %% [markdown]
# # 샘플 테스트

# %%
st1 = [100, 110, 90, 105, 95, 102, 98]
st2 = [100, 130, 70, 120, 80, 160, 40]
x = list (  range(0, len(st1)))

# %%
sum(st2)
# Out:
# 700

# %%
#평균, 분산, 표준편차

# %%
import numpy as np

# %%
st1Mean = np.mean(st1)
st2Mean = np.mean(st2)
print(st1Mean, st2Mean)
# Out:
# 100.0 100.0

# %% [markdown]
# ### 분산 과 표준편차

# %%
# 분산 variance (증폭된 차이의 평균을 ROOT로 다운)
# 표준편차 standard_deviation

st1Mean = np.mean(st1)
st1Len = len(st1)
diffSum = 0
for eachitem in st1:
    diffSum = diffSum + (st1Mean-eachitem) ** 2

# %%
stdValue = np.sqrt(diffSum / (st1Len-1))
stdValue
# Out:
# np.float64(6.557438524302)

# %% [markdown]
# [실습] st2 데이터 활용 분산, 표준편차를 구해보세요
# (표본 대상)

# %%
# 한글 폰트 설치
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

# 설치된 폰트 확인
import matplotlib.font_manager as fm
import matplotlib.pyplot as plt
import seaborn as sns
import os

# 설치된 NanumGothic 폰트의 경로 확인
fontpath = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'

# 폰트를 Matplotlib에 등록
font = fm.FontProperties(fname=fontpath)
fm.fontManager.addfont(fontpath)

# 폰트 캐시 삭제 (필요 시)
matplotlib_cache_dir = os.path.expanduser('~/.cache/matplotlib')
if os.path.exists(matplotlib_cache_dir):
    import shutil
    shutil.rmtree(matplotlib_cache_dir)

# 한글 폰트를 기본 폰트로 설정
plt.rc('font', family='NanumGothic')
plt.rc('axes', unicode_minus=False)  # 마이너스 기호 깨짐 방지
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 126101 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Selecting previously unselected package fonts-nanum-coding.
# Preparing to unpack .../fonts-nanum-coding_2.5-3_all.deb ...
# Unpacking fonts-nanum-coding (2.5-3) ...
# Selecting previously unselected package fonts-nanum-eco.
# Preparing to unpack .../fonts-nanum-eco_1.000-7_all.deb ...
# Unpacking fonts-nanum-eco (1.000-7) ...
# Selecting previously unselected package fonts-nanum-extra.
# Preparing to unpack .../fonts-nanum-extra_20200506-1_all.deb ...
# Unpacking fonts-nanum-extra (20200506-1) ...
# Setting up fonts-nanum-extra (20200506-1) ...
# ...

# %%
# tensforflow: 딥러닝
# scikit-learn :머신러닝
# pandas # 행과열 데ㅣ터 분석
# selenium!! # 브라저 자동화
# beautifulsoup !!! 텍스를 -> 태그로 인식할수 있게 예쁘게 뜬거고!
# requests 요청!!
# matplotlib !!! 시각화용 라이브러리
# seaborn!!!

# %%
st1
st2
# Out:
# [100, 130, 70, 120, 80, 160, 40]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(st1, label = "TV")
plt.plot(st2, label = "핸드폰")
plt.legend(loc=0)

# %% [markdown]
# # 1. 시각화 라이브러리

# %% [markdown]
# # 1. matpotlib 활용 차트 그리기

# %% [markdown]
# ### (1) 차트 그리기

# %%
# import pandas as pd

# selloutData = pd.read_csv("../dataset/kopo_product_volume.csv")

# selloutData["WEEK"] = selloutData.YEARWEEK.astype(str).str[4:6].astype(int)

# selloutData.head(2)

# groupKey = ["REGIONID","PRODUCTGROUP","WEEK"]

# groupData = selloutData.groupby(groupKey)["VOLUME"].agg(["mean"]).reset_index()
# groupData.rename(columns={"mean":"MEAN_VOLUME"}, inplace=True)

# %%
# groupData["MEAN_VOLUME"] = groupData.MEAN_VOLUME.astype(int)

# %%
# groupDataS01 = groupData.loc[ groupData.PRODUCTGROUP=="ST0001"]
# groupDataS02 = groupData.loc[ groupData.PRODUCTGROUP=="ST0002"]
# groupDataS01.head(5)

# %%
# groupDataS01.to_csv("../dataset/ST0001DATA.csv", index=False)
# groupDataS02.to_csv("../dataset/ST0002DATA.csv", index=False)

# %%
import pandas as pd

st0001LocalUrl = "../dataset/ST0001DATA.csv"
st0002LocalUrl = "../dataset/ST0002DATA.csv"
st0001GitUrl = "https://raw.githubusercontent.com/hyokwan/python-lecture/master/dataset/st0001data.csv"
st0002GitUrl = "https://raw.githubusercontent.com/hyokwan/python-lecture/master/dataset/st0002data.csv"

groupDataS01 = pd.read_csv(st0001GitUrl)
groupDataS02 = pd.read_csv(st0002GitUrl)
groupDataS02.head()
# Out:
#   REGIONID PRODUCTGROUP  WEEK  MEAN_VOLUME
# 0      A01       ST0002     1       158086
# 1      A01       ST0002     2       128312
# 2      A01       ST0002     3       127417
# 3      A01       ST0002     4       157127
# 4      A01       ST0002     5       197415

# %%
#필요 라이브러리 정의
import matplotlib.pyplot as plt

# jupyter 상에서 바로 그래프 시현
# %matplotlib inline

x=groupDataS01.WEEK
y=groupDataS01.MEAN_VOLUME
# x=list(groupDataS01.WEEK)
# y=list(groupDataS01.MEAN_VOLUME)

# X축 값 범위 지정
plt.xticks( range(min(x),max(x),3) )
plt.plot(x,y)

# %% [markdown]
# ### (2) 차트 꾸미기

# %%
# x축 값 범위 지정
plt.xticks( range(min(x),max(x),3)  )
# X, Y축 라벨
plt.xlabel("week")
plt.ylabel("avg_volume")
# 차트 제목
plt.title("weekly trend")
# 선색상, 종류, 굵기 변경
plt.plot(x,y, "bo-", lw=2.5)

# %% [markdown]
# ### (3) 다중차트 라벨 설정

# %%
x=groupDataS01.WEEK
y=groupDataS01.MEAN_VOLUME
y2=groupDataS02.MEAN_VOLUME

plt.xticks( range(min(x),max(x),3)  )
plt.plot(x,y,"go--", label="ST0001")
plt.plot(x,y2,"bo-", label="ST0002")

# 각 차트 별 표식 생성
plt.legend(loc=0)

# %% [markdown]
# ### 종합실습

# %%
#필요 라이브러리 정의
import matplotlib.pyplot as plt

# 커맨드뷰에서 차트 시연
# %matplotlib inline
x=groupDataS01.WEEK
y=groupDataS01.MEAN_VOLUME
y2=groupDataS02.MEAN_VOLUME

# 차트 꾸미기
plt.plot(x,y,"go--", label="ST0001")
plt.plot(x,y2,"bo--", label="ST0002")
plt.grid(True) #그리드 표기
plt.xlabel('week') # x축 라벨
plt.ylabel('mean_volume') # y축 라벨
plt.title('volume by week') # 차트 제목
# Out:
# Text(0.5, 1.0, 'volume by week')

# %% [markdown]
# ### [실습]
# ../dataset/feature_regression_example.csv
#  데이터를 활용하여
# 2015년도 자료만 활용하여
# x축: week, y축: qty를 라인차트로 그리세요

# %%
import pandas as pd
featuresLocalUrl = "../dataset/feature_regression_example.csv"
featuresGitUrl = "https://raw.githubusercontent.com/hyokwan/python-lecture/master/dataset/feature_regression_example.csv"
featuresData =  pd.read_csv(featuresGitUrl)

# %%
import pandas as pd

featuresData =  pd.read_csv(featuresGitUrl)

featuresData2015 = featuresData[ (featuresData.YEARWEEK >= 201501) &
                                (featuresData.YEARWEEK <= 201552)]

featuresData2016 = featuresData[ (featuresData.YEARWEEK >= 201601) &
                                (featuresData.YEARWEEK <= 201652)]

featuresData2016.head()
# Out:
#           REGIONID PRODUCTGROUP      PRODUCT      ITEM  YEARWEEK  YEAR  WEEK  \
# 53  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201601  2016     1
# 54  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201602  2016     2
# 55  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201603  2016     3
# 56  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201604  2016     4
# 57  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201605  2016     5
#
#      QTY HOLIDAY  HCLUS PROMOTION  PRO_PERCENT
# 53   711       N      4         Y     0.237768
# 54    16       N      4         N     0.000000
# 55    15       Y      2         N     0.000000
# 56   424       N      4         Y     0.237768
# 57  1139       N      4         Y     0.237768

# %%
#필요 라이브러리 정의
import matplotlib.pyplot as plt

# 커맨드뷰에서 차트 시연
# %matplotlib inline
# 팝업 창 활용하여 차트 시연
x=featuresData2015[["WEEK"]]
y = featuresData2015[["QTY"]]
y2 = featuresData2016[["QTY"]]
# 차트 꾸미기, legend
plt.plot(x,y,"g", label="2015")
plt.plot(x,y2,"bo--", label="2016")
plt.legend(loc=0)

# %%
### promotion 값도 같이 시각화!

# %% [markdown]
# # 2. matplotlib 활용 시각화 고급

# %% [markdown]
# ### (1) 서브플롯 그리기

# %%
import pandas as pd

st0001LocalUrl = "../dataset/ST0001DATA.csv"
st0002LocalUrl = "../dataset/ST0002DATA.csv"
st0001GitUrl = "https://raw.githubusercontent.com/hyokwan/python-lecture/master/dataset/st0001data.csv"
st0002GitUrl = "https://raw.githubusercontent.com/hyokwan/python-lecture/master/dataset/st0002data.csv"

groupDataS01 = pd.read_csv(st0001GitUrl)
groupDataS02 = pd.read_csv(st0002GitUrl)

# 필요 라이브러리 정의
import matplotlib.pyplot as plt
# 팝업 창 활용하여 차트 시연
x=groupDataS01.WEEK
y=groupDataS01.MEAN_VOLUME
y2=groupDataS02.MEAN_VOLUME

fig = plt.figure(figsize=(14,4))
# 첫번째 차트
ax1 = fig.add_subplot(121)
ax1.plot(x,y, 'bo-',lw=1.5, label = 'ST0001')
ax1.grid(True)
ax1.legend(loc=0)
ax1.set_xlabel('ax1_index')
ax1.set_ylabel('ax1_value')
ax1.set_title('ax1_title')
# 두번째 차트
ax2 = fig.add_subplot(122)
ax2.plot(x,y2, 'go-', lw=1.5, label='ST0002')
ax2.grid(True)
ax2.legend(loc=0)
ax2.set_xlabel('ax2_index')
ax2.set_ylabel('ax2_value')
ax2.set_title('ax2_title')
# Out:
# Text(0.5, 1.0, 'ax2_title')

# %% [markdown]
# ### (2) 이중축 그리기

# %%
# import matplotlib
# font = {'family' : 'normal',
#         'weight' : 'bold',
#         'size'   : 14}

# %%
#필요 라이브러리 정의
import matplotlib.pyplot as plt

# 팝업 창 활용하여 차트 시연
x=groupDataS01.WEEK
y=groupDataS01.MEAN_VOLUME
y2=groupDataS02.MEAN_VOLUME

# 이중축
fig = plt.figure(figsize=(14,4))
ax1 = fig.add_subplot(1,1,1)
#figure, ax1 = plt.subplots(figsize=(10,5))
ax1.plot(x,y, 'bo-',lw=1.5, label = 'ST0001')
ax1.grid(True)
ax1.legend(loc=0)
ax1.set_ylabel('ax1_value')
ax1.set_xlabel('ax1_index')
plt.title('subplot')
ax2 = ax1.twinx()
ax2.plot(x,y2, 'go-', lw=1.5, label='ST0002')
ax2.legend(loc=4)
ax2.set_ylabel('ax2_value')
# Out:
# Text(0, 0.5, 'ax2_value')

# %% [markdown]
# ### [실습]
# ../dataset/feature_regression_example.csv
# 2015년도 자료만 활용하여
# x축: week 이중축으로 qty, pro_percent를
# 차트로 그리세요

# %%
import pandas as pd

featuresLocalUrl = "../dataset/feature_regression_example.csv"
featuresGitUrl = "https://raw.githubusercontent.com/hyokwan/python-lecture/master/dataset/feature_regression_example.csv"
featuresData =  pd.read_csv(featuresGitUrl)

featuresData2015 = featuresData[ (featuresData.YEARWEEK >= 201501) &
                                (featuresData.YEARWEEK <= 201552)]

featuresData2015.head()
# Out:
#          REGIONID PRODUCTGROUP      PRODUCT      ITEM  YEARWEEK  YEAR  WEEK  \
# 0  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201501  2015     1
# 1  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201502  2015     2
# 2  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201503  2015     3
# 3  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201504  2015     4
# 4  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201505  2015     5
#
#     QTY HOLIDAY  HCLUS PROMOTION  PRO_PERCENT
# 0  1225       Y      1         Y     0.209442
# 1   968       N      4         Y     0.209442
# 2  1209       N      4         Y     0.208155
# 3  1810       Y      2         Y     0.208155
# 4  1773       N      4         Y     0.208155

# %%
y2 = featuresData2015["PRO_PERCENT"]
print(type(y2))
# Out:
# <class 'pandas.core.series.Series'>

# %%
#필요 라이브러리 정의
import matplotlib.pyplot as plt

# 팝업 창 활용하여 차트 시연
x=featuresData2015[["WEEK"]]
y = featuresData2015["QTY"]
y2 = featuresData2015[["PRO_PERCENT"]]

# 이중축
fig = plt.figure(figsize=(10,5))
ax1 = fig.add_subplot(1,1,1)
plt.plot(x,y, 'bo--',lw=1.5, label = '1st')
plt.grid(True)
plt.legend(loc=2)
plt.ylabel('qty')
plt.title('subplot')
ax2 = ax1.twinx()
plt.plot(x,y2, 'g', lw=1.5, label='2nd')
plt.legend(loc=4)
plt.xlabel('week')
plt.ylabel('promotion')
# Out:
# Text(0, 0.5, 'promotion')

# %% [markdown]
# ### (3) 막대차트 그리기

# %%
#필요 라이브러리 정의
import matplotlib.pyplot as plt

x=groupDataS01.WEEK
y=groupDataS01.MEAN_VOLUME

fig = plt.figure(figsize=(10,5))

ax1 = fig.add_subplot(111)
ax1.bar(x,y, width=0.8, label='ST0001')
ax1.legend(loc=0)
ax1.set_xlabel('WEEK')
ax1.set_ylabel('VOLUME')
# Out:
# Text(0, 0.5, 'VOLUME')

# %% [markdown]
# ### (4) 파이차트 그리기

# %%
# 필요 라이브러리 정의
import matplotlib.pyplot as plt

# 라벨 및 값 정의
groupLabel = ['A', 'B', 'C']
groupValue = [95, 54, 25]

# 파이차트 시각화
fig = plt.figure(figsize=(10,5))
ax1 = fig.add_subplot(1,1,1)
ax1.pie(x=groupValue,
       labels=groupLabel,
       autopct="%1.2f%%",
       textprops={'fontsize': 12} )
ax1.legend(loc=0)

# %%
# 예시 데이터프레임
data = {'과일': ['사과', '바나나', '오렌지', '포도'],
        '수량': [30, 15, 45, 10]}
df = pd.DataFrame(data)
df
# Out:
#     과일  수량
# 0   사과  30
# 1  바나나  15
# 2  오렌지  45
# 3   포도  10

# %%
# 파이차트 그리기
plt.figure(figsize=(6, 6))
plt.pie(x=df['수량'], labels=df['과일'], autopct='%1.1f%%')
plt.title('과일별 수량 비율')
plt.axis('equal')  # 원형 유지
plt.show()

# %% [markdown]
# # 3. Seaborn

# %%
import seaborn as sns
import pandas as pd
# %matplotlib inline

customerLocalUrl = "../dataset/customerdata.csv"
customerGitUrl = "https://raw.githubusercontent.com/hyokwan/python-lecture/master/dataset/customerdata.csv"
csData = pd.read_csv(customerGitUrl)
csData.head(2)
# Out:
#    CUSTID    AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 0  A13566  4273.90000    3            6    1.679181  Big-Screen-lover
# 1  A14219  3642.44195    2            4    2.682023      Sleeping-dog

# %% [markdown]
# ### (1) 카운트 차트(count plot)

# %%
import seaborn as sns

# 예쁜 스타일 적용
# sns.set_theme(style='whitegrid')  # 밝고 깔끔한 배경
# sns.set_palette('pastel')         # 부드러운 파스텔 톤
sns.set_theme(style='darkgrid')  # 또는 sns.set_style('darkgrid')
sns.countplot(data = csData, x = 'EMI', order = csData.EMI.value_counts().sort_values(ascending=False).index)
# Out:
# <Axes: xlabel='EMI', ylabel='count'>

# %%
sns.countplot(data = csData, x="EMI", hue="CUSTTYPE", order = csData.EMI.value_counts(ascending=True).index)
# Out:
# <Axes: xlabel='EMI', ylabel='count'>

# %% [markdown]
# ### (2) 히스토그램 (dist plot)

# %%
import matplotlib.pyplot as plt

fig = plt.figure( figsize=(18, 6))
ax1 = fig.add_subplot(1, 2, 1)

sns.histplot(data=csData, x=csData.AVGPRICE, ax=ax1)
ax2 = fig.add_subplot(1, 2,2)
sns.kdeplot(data=csData, x=csData.AVGPRICE, ax=ax2)
# Out:
# <Axes: xlabel='AVGPRICE', ylabel='Density'>

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
figure = plt.figure(figsize=(18, 6))

# 히스토그램 그래프 (kde=False)
ax1 = plt.subplot(1, 2, 1)
sns.histplot(csData.AVGPRICE, kde=False, ax=ax1)

# KDE 그래프 (hist=False)
ax2 = plt.subplot(1, 2, 2)
sns.kdeplot(csData.AVGPRICE, ax=ax2)
# Out:
# <Axes: xlabel='AVGPRICE', ylabel='Density'>

# %% [markdown]
# ### (3) 바 차트 (bar plot)

# %%
sns.barplot(x="EMI", y="AVGPRICE", data = csData,
         hue = "CUSTTYPE", ci = "sd")
# Out:
# <ipython-input-39-bfc9be547532>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(x="EMI", y="AVGPRICE", data = csData,
# <Axes: xlabel='EMI', ylabel='AVGPRICE'>

# %% [markdown]
# ### (4) 박스 차트 (box plot)

# %%
sns.boxplot(data=csData, x="EMI", y="AVGPRICE")
# Out:
# <Axes: xlabel='EMI', ylabel='AVGPRICE'>

# %% [markdown]
# ### (5) 선 차트 (line plot)

# %%
import pandas as pd
featuresLocalUrl = "../dataset/feature_regression_example.csv"
featuresGitUrl = "https://raw.githubusercontent.com/hyokwan/python-lecture/master/dataset/feature_regression_example.csv"
featuresData =  pd.read_csv(featuresGitUrl)

# %%
sns.lineplot(data=featuresData.loc[featuresData.YEAR==2015],
                                 x="WEEK", y="QTY")
# Out:
# <Axes: xlabel='WEEK', ylabel='QTY'>

# %% [markdown]
# ### (6) LM 차트 (lm plot)

# %%
sns.lmplot(data=featuresData, x="PRO_PERCENT",y="QTY")
# 제목 추가
plt.title("판매량 VS 프로모션")
# Out:
# Text(0.5, 1.0, '판매량 VS 프로모션')

# %%
featuresData.corr(numeric_only=True)
# Out:
#              YEARWEEK      YEAR      WEEK       QTY     HCLUS  PRO_PERCENT
# YEARWEEK     1.000000  0.956598  0.275593  0.112267 -0.071586     0.404889
# YEAR         0.956598  1.000000 -0.016493  0.028931  0.028593     0.321193
# WEEK         0.275593 -0.016493  1.000000  0.289766 -0.339943     0.329705
# QTY          0.112267  0.028931  0.289766  1.000000 -0.537230     0.700195
# HCLUS       -0.071586  0.028593 -0.339943 -0.537230  1.000000    -0.545619
# PRO_PERCENT  0.404889  0.321193  0.329705  0.700195 -0.545619     1.000000

# %% [markdown]
# ### (7) 조인트 차트 (joint plot)

# %%
sns.jointplot(data=csData, x= "AVGPRICE", y = "PRODUCTAGE")

# %% [markdown]
# ### [실습] https://github.com/mwaskom/seaborn-data 내 flights 및 tips 데이터를 활용하여 데이터를 시각화하세요

# %% [markdown]
# # 한글깨짐현상 가이드

# %%
# import matplotlib.pyplot as plt
# import matplotlib

# font_name = matplotlib.font_manager.FontProperties(fname='C:/Windows/Fonts/malgun.ttf').get_name()
# matplotlib.rc('font', family=font_name)
# print(font_name)
